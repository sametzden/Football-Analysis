# %% [markdown]
# Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="uZPhn1mSd3c6apO9MCF4")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolo26:: 100%|██████████| 147802/147802 [02:47<00:00, 882.79it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolo26:: 100%|██████████| 1338/1338 [00:00<00:00, 8381.32it/s]

# %%
dataset.location
# Out:
# '/home/samet/Projects/football_analysis/training/football-players-detection-1'

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train')

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test')

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %%
dataset.location
# Out:
# '/home/samet/Projects/football_analysis/training/football-players-detection-1'

# %% [markdown]
# ## Training

# %%
# !yolo task=detect mode=train model=yolo26m.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.3 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3770MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/samet/Projects/football_analysis/training/football-players-detection-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/samet/Projects/football_analysis/training/runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/samet/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 5.1MB/s 0.1s 0.1s<0.1s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   2804784  ultralytics.nn.modules.head.Detect           [4, 1, True, [256, 512, 512]]
# YOLO26m summary: 280 layers, 21,779,056 parameters, 21,779,056 gradients, 74.7 GFLOPs
#
# Transferred 756/768 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 1.6MB/s 3.3s.2s<0.1s7ss
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2953.2±1935.0 MB/s, size: 226.0 KB)
# train: Scanning /home/samet/Projects/football_analysis/training/football-players-detection-1/train/labels... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 2.7Kit/s 0.2s0.1ss
# train: New cache created: /home/samet/Projects/football_analysis/training/football-players-detection-1/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2175.3±1561.5 MB/s, size: 209.9 KB)
# val: Scanning /home/samet/Projects/football_analysis/training/football-players-detection-1/valid/labels... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 824.7it/s 0.0s
# val: New cache created: /home/samet/Projects/football_analysis/training/football-players-detection-1/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# Plotting labels to /home/samet/Projects/football_analysis/training/runs/detect/train2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/samet/Projects/football_analysis/training/runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING ⚠️ CUDA out of memory with batch=16. Reducing to batch=8 and retrying (1/3).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1484.4±2451.0 MB/s, size: 235.7 KB)
# train: Scanning /home/samet/Projects/football_analysis/training/football-players-detection-1/train/labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 320.9Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1580.2±948.1 MB/s, size: 234.2 KB)
# val: Scanning /home/samet/Projects/football_analysis/training/football-players-detection-1/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 2.6Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# : 0% ──────────── 0/39  1.5s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING ⚠️ CUDA out of memory with batch=8. Reducing to batch=4 and retrying (2/3).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 167.0±106.0 MB/s, size: 229.2 KB)
# train: Scanning /home/samet/Projects/football_analysis/training/football-players-detection-1/train/labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 213.9Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2044.4±957.5 MB/s, size: 218.8 KB)
# val: Scanning /home/samet/Projects/football_analysis/training/football-players-detection-1/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 2.2Mit/s 0.0s
# Exception in thread Thread-27 (_pin_memory_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/samet/Projects/football_analysis/cv_env/lib/python3.12/site-packages/torch/utils/data/_utils/pin_memory.py", line 59, in _pin_memory_loop
#     do_one_step()
#   File "/home/samet/Projects/football_analysis/cv_env/lib/python3.12/site-packages/torch/utils/data/_utils/pin_memory.py", line 35, in do_one_step
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/samet/Projects/football_analysis/cv_env/lib/python3.12/site-packages/torch/multiprocessing/reductions.py", line 541, in rebuild_storage_fd
#     fd = df.detach()
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/resource_sharer.py", line 86, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 525, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 962, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# : 0% ──────────── 0/77  3.6s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.63G      1.317      1.592   0.001146        222        640: 100% ━━━━━━━━━━━━ 153/153 4.1it/s 37.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s3.1s
#                    all         38        905      0.728      0.495      0.595      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.72G      1.316     0.7081   0.001133         84        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.798      0.707      0.767      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.71G      1.341     0.6085    0.00114        105        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.2s
#                    all         38        905      0.807      0.742      0.788      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.72G      1.314     0.5774   0.001106        200        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.2s
#                    all         38        905      0.894      0.708      0.788      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.73G      1.332     0.5399   0.001127        209        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.3s
#                    all         38        905      0.879      0.783      0.825      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.72G      1.307      0.511   0.001091         80        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.2s
#                    all         38        905      0.912       0.74      0.832      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.71G      1.256     0.4666   0.001047         90        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.2s
#                    all         38        905      0.848      0.776      0.827      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.72G      1.219     0.4735  0.0009909         94        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.871      0.754      0.819      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.77G      1.174     0.4391  0.0009718        124        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.2s
#                    all         38        905      0.862       0.78      0.836      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.73G       1.18       0.43  0.0009677        193        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.873      0.779       0.83      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.67G      1.187     0.4421  0.0009808        181        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.947      0.761      0.843      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.75G       1.19     0.4271    0.00101        137        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.4s1.2s
#                    all         38        905      0.932      0.778       0.86       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.75G      1.166     0.4044  0.0009455        123        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.931      0.791       0.85      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.72G      1.157     0.3967  0.0009255        132        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905       0.89      0.777      0.848      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.74G      1.149      0.388  0.0009561        183        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.2s
#                    all         38        905      0.907      0.833      0.863      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.72G      1.139     0.3808  0.0009189        160        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905       0.92      0.842      0.862      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.77G      1.129     0.3707   0.000932        178        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.913      0.838       0.86      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.75G      1.119     0.3648  0.0009063        154        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.956      0.825      0.868      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.75G      1.088     0.3582   0.000871        209        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.943      0.796      0.848      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.69G      1.131     0.3805  0.0008934        203        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.931      0.827       0.86      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.77G      1.152     0.3774  0.0009269        153        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.909      0.832      0.865        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.75G      1.105     0.3537  0.0008562        133        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.901      0.824      0.853       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.72G      1.109     0.3574  0.0008805        170        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.901      0.817      0.856      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.72G      1.076      0.348  0.0008326         64        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.905      0.814      0.856      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.71G      1.112      0.354   0.000877        192        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.934       0.78      0.839      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.74G      1.081      0.349  0.0008527         85        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.938      0.804       0.85      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.73G      1.061     0.3374  0.0008347        230        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.4s1.2s
#                    all         38        905      0.911      0.832      0.858      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.75G      1.088     0.3458  0.0008614         96        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.918      0.806      0.862      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.73G      1.105     0.3456  0.0008764         88        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.947      0.801      0.863      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.72G      1.089     0.3457  0.0008462        161        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.957      0.792      0.865      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.74G      1.063     0.3396  0.0008491        163        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.933       0.81      0.867      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.67G      1.018     0.3242  0.0008214        106        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.973      0.806      0.865      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.71G      1.023     0.3194   0.000807        151        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905       0.89       0.82      0.847      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.71G      1.026      0.321   0.000811        182        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0.959      0.787      0.863      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.73G      1.019     0.3174  0.0008013        108        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s1.2s
#                    all         38        905      0
9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.3s
#                    all         38        905      0.939      0.827      0.871      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.72G      0.872      0.257  0.0006411         89        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.945      0.811      0.866      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.74G     0.8602     0.2522  0.0006458        111        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 36.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.4s1.2s
#                    all         38        905      0.972      0.791      0.867      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100       2.7G     0.8591     0.2521  0.0006416        196        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.934      0.837      0.876      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.74G     0.8563     0.2542  0.0006265        157        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.935      0.812      0.863      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.71G     0.8468     0.2484  0.0006295        162        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.932      0.811      0.865      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.74G     0.8157     0.2408  0.0006265        158        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.926      0.818      0.866      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.69G     0.8523     0.2517  0.0006146        155        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905       0.97      0.818       0.87       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.71G     0.8482     0.2494   0.000636        157        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.917      0.831      0.862      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.71G     0.8348     0.2461  0.0006174        189        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.909      0.832      0.865      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.76G       0.81     0.2368  0.0006089        197        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.931      0.818      0.856      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.71G     0.8353     0.2448   0.000617        198        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 36.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s1.2s
#                    all         38        905      0.967      0.798      0.864      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100       2.7G     0.8044     0.2368   0.000608        173        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.2s
#                    all         38        905      0.957      0.809      0.866      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.73G     0.8236     0.2426  0.0006095        160        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.2s
#                    all         38        905      0.972      0.803      0.856      0.615
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.69G     0.7706     0.2231  0.0006201         90        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.2s
#                    all         38        905      0.966      0.826      0.873       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.69G     0.7599     0.2217  0.0006153         95        640: 100% ━━━━━━━━━━━━ 153/153 4.4it/s 35.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s1.3s
#                    all         38        905      0.954      0.798      0.865      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.69G     0.7551      0.219  0.0006028         90        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.2s
#                    all         38        905      0.948      0.805       0.87      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.69G     0.7424     0.2142  0.0005976         93        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.2s
#                    all         38        905      0.936      0.804      0.862      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.69G     0.7296     0.2141  0.0005939         88        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.2s
#                    all         38        905      0.915       0.83      0.859      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.64G     0.7484     0.2186  0.0005968         93        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s1.3s
#                    all         38        905      0.964      0.802      0.857      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.67G     0.7243      0.211  0.0005926         96        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.3s
#                    all         38        905      0.957      0.801      0.851      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.69G     0.7378     0.2145  0.0005887         94        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s1.4s
#                    all         38        905      0.946      0.808      0.855      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.68G     0.7175     0.2084   0.000585         93        640: 100% ━━━━━━━━━━━━ 153/153 4.2it/s 36.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.2s
#                    all         38        905      0.953      0.813      0.858      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.69G     0.7279     0.2105  0.0005831         92        640: 100% ━━━━━━━━━━━━ 153/153 4.3it/s 35.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.2s
#                    all         38        905       0.95      0.808       0.86      0.612
#
# 100 epochs completed in 1.019 hours.
# Optimizer stripped from /home/samet/Projects/football_analysis/training/runs/detect/train2/weights/last.pt, 44.0MB
# Optimizer stripped from /home/samet/Projects/football_analysis/training/runs/detect/train2/weights/best.pt, 44.0MB
#
# Validating /home/samet/Projects/football_analysis/training/runs/detect/train2/weights/best.pt...
# Ultralytics 8.4.21 🚀 Python-3.12.3 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3770MiB)
# YOLO26m summary (fused): 132 layers, 20,352,536 parameters, 0 gradients, 67.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.1s
#                    all         38        905      0.936       0.84      0.886       0.63
#                   ball         35         35      0.944      0.482      0.604      0.267
#             goalkeeper         27         27      0.894      0.941      0.971      0.746
#                 player         38        754      0.961      0.984      0.994      0.803
#                referee         38         89      0.946      0.955      0.977      0.703
# Speed: 0.3ms preprocess, 9.8ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/samet/Projects/football_analysis/training/runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train
